# %% [markdown]
# <a href="https://colab.research.google.com/github/eminesengultiras/Algoritmalar-Veri-Yapilari-Ve-Yapay-Zeka-Uygulamalari-Atolyesi/blob/main/phyton_ders_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Merhaba, Python Veri Yapıları ve Algoritmalar / Ders 8")
# Out:
# Merhaba, Python Veri Yapıları ve Algoritmalar / Ders 8

# %%
import sys  # import python programlama dilinde yazılıma kütüphane eklemeye yarayan bir kod blogudur.
print(sys.version)
# Out:
# 3.12.13 (main, Mar  4 2026, 09:23:07) [GCC 11.4.0]

# %%
from google.colab import drive # google colab - drive bağlantısı

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

os.chdir('/content/drive/My Drive/GoogleColab')

# !pwd # bize kodun çıktısını dosya yolu olarak veren kod blogudur.
# Out:
# /content/drive/My Drive/GoogleColab

# %%
print("Merhaba Dünya'
# Out:
#   File "/tmp/ipykernel_2860/3113429097.py", line 1
#     print("Merhaba Dünya'
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
x = 5 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_2860/1806623527.py in <cell line: 0>()
# ----> 1 x = 5 / 0
#
# ZeroDivisionError: division by zero

# %%
try:
  sayi = int(input("Bir sayı gir!!"))
  print(sayi)
except ValueError:
  print("Hata: Girilen veri sayı değildir!!")
else:
  print("Giriş işlemi başarılı")
finally:
  print("Program sonlandırıldı.")
# Out:
# Bir sayı gir!!56
# 56
# Giriş işlemi başarılı
# Program sonlandırıldı.

# %%
try:
  s = 5 / 0
  degisken = int(s)
except ZeroDivisionError:
  print("Dönüşüm Hatası")
else:
  print("işlem tamamlandı", degisken)
finally:
  print("program bitti")
# Out:
# Dönüşüm Hatası
# program bitti

# %%
while True:
  girdi = input("Bir sayı gir(Çıkmak için 'q' bas)")
  if girdi.lower() == 'q':
    print("Programdan Çıkılıyor")
    break
  try:
    sayi = float(girdi)
  except ValueError:
    print("Hata: Girilen veri sayı değildir!!")
    continue

  if sayi == 0:
    print("Sayı sıfırdır")
  elif sayi>0:
    print("Sayı pozitif")
  else:
    print("Sayı negatif")

  break
# Out:
# Bir sayı gir(Çıkmak için 'q' bas)9
# Sayı pozitif
